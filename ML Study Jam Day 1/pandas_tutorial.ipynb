# %%
import pandas as pd

people_dict = { "weight": pd.Series([68, 83, 112],index=["alice", "bob", "charles"]),   "birthyear": pd.Series([1984, 1985, 1992], index=["bob", "alice", "charles"], name="year"),
"children": pd.Series([0, 3], index=["charles", "bob"]),
"hobby": pd.Series(["Biking", "Dancing"], index=["alice", "bob"]),}

# %%
people = pd.DataFrame(people_dict)
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
people.sort_values(by=['birthyear'],ascending=[True],inplace=False)
# Out:
#          weight  birthyear  children    hobby
# bob          83       1984       3.0  Dancing
# alice        68       1985       NaN   Biking
# charles     112       1992       0.0      NaN

# %%
people['birthyear']
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %%
people['param']=[1,2,3]

# %%
people.head()
#tail,info,describe
# Out:
#          weight  birthyear  children    hobby  param
# alice        68       1985       NaN   Biking      1
# bob          83       1984       3.0  Dancing      2
# charles     112       1992       0.0      NaN      3

# %%
people.drop(columns='birthyear')
# Out:
#          weight  children    hobby  param
# alice        68       NaN   Biking      1
# bob          83       3.0  Dancing      2
# charles     112       0.0      NaN      3

# %%
people.loc['alice']
# Out:
# weight           68
# birthyear      1985
# children        NaN
# hobby        Biking
# param             1
# Name: alice, dtype: object

# %%
people.iloc[0]
# Out:
# weight           68
# birthyear      1985
# children        NaN
# hobby        Biking
# param             1
# Name: alice, dtype: object
